# %%
import cv2
import torch
import numpy as np
import os
import glob
import subprocess
from google.colab.patches import cv2_imshow
from PIL import Image
import torchvision.transforms as transforms
from torchvision import models
import torch.nn.functional as F

# Tikriname ir įdiegiame trūkstamas bibliotekas
required_packages = ["ultralytics", "deep_sort_realtime"]
for package in required_packages:
    try:
        __import__(package)
    except ModuleNotFoundError:
        print(f"📦 Diegiama: {package}")
        try:
            subprocess.check_call(["pip", "install", package])
        except subprocess.CalledProcessError as e:
            print(f"❌ Klaida diegiant {package}: {e}")
            exit()

import ultralytics
import deep_sort_realtime

from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# Nustatome katalogus
video_directory = "input_videos"
sample_directory = "car"
output_directory = "output_videos"
os.makedirs(output_directory, exist_ok=True)

# Naudojame MobileNetV2 vietoj ResNet18 greitesniam veikimui
vehicle_model = models.mobilenet_v2(pretrained=True)
vehicle_model.eval()
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

def extract_features(image):
    image = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    image = transform(image).unsqueeze(0)
    with torch.no_grad():
        features = vehicle_model(image)
    return features

# Įkeliame pateiktas automobilio pavyzdžių nuotraukas
sample_images = []
sample_features = []
for img_path in glob.glob(os.path.join(sample_directory, "*.jpg")):
    img = cv2.imread(img_path)
    sample_images.append(img)
    sample_features.append(extract_features(img))

# YOLO modelis automobilio aptikimui
model = YOLO("yolov8n.pt")  # Optimizuota nano versija greitesniam veikimui

# DeepSORT ReID modelis sekimui
tracker = DeepSort(max_age=50, max_iou_distance=0.4)  # Pagerintas stabilumas

# Apdorosime visus vaizdo įrašus
video_files = sorted(glob.glob(os.path.join(video_directory, "*.mp4")))
for video_path in video_files:
    print(f"🔄 Apdorojamas vaizdo įrašas: {video_path}")

    # Vaizdo įrašo įkėlimas
    capture = cv2.VideoCapture(video_path)
    width = int(capture.get(3))
    height = int(capture.get(4))
    fps = int(capture.get(cv2.CAP_PROP_FPS))

    output_filename = os.path.join(output_directory, os.path.basename(video_path))
    out = cv2.VideoWriter(output_filename, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    tracked_cars = {}
    target_car_id = None
    best_match_threshold = 0.6  # Slenkstis, kad filtruotų klaidingus atitikmenis

    while capture.isOpened():
        ret, frame = capture.read()
        if not ret:
            break

        # Aptinkame automobilius su YOLOv8
        results = model(frame)[0]
        detections = []
        best_match_score = float('inf')  # L2 atstumas, mažesnis geresnis
        best_bbox = None

        for result in results.boxes.data:
            x1, y1, x2, y2, conf, cls = result.tolist()
            if int(cls) == 2 or int(cls) == 7:
                cropped_car = frame[int(y1):int(y2), int(x1):int(x2)]
                car_features = extract_features(cropped_car)
                match_scores = [torch.dist(car_features, sample_feat).item() for sample_feat in sample_features]
                cosine_scores = [F.cosine_similarity(car_features, sample_feat).item() for sample_feat in sample_features]

                min_distance = min(match_scores)
                max_similarity = max(cosine_scores)

                if min_distance < best_match_score and max_similarity > best_match_threshold:
                    best_match_score = min_distance
                    best_bbox = (x1, y1, x2, y2)

        if best_bbox:
            detections.append((best_bbox, 1.0, 'car'))

        # Atlikti sekimą su DeepSORT
        tracker_outputs = tracker.update_tracks(detections, frame=frame)

        for track in tracker_outputs:
            if track.is_confirmed():
                x1, y1, x2, y2 = track.to_tlbr()
                track_id = track.track_id

                if target_car_id is None:
                    target_car_id = track_id

                if track_id == target_car_id:
                    cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 3)
                    cv2.putText(frame, f'Sekamas automobilis {track_id}', (int(x1), int(y1) - 10),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 3)
                    print(f"🚗 Sekamas automobilis ID: {track_id} ties ({x1}, {y1}, {x2}, {y2})")

        out.write(frame)

    capture.release()
    out.release()
    cv2.destroyAllWindows()
    print(f"✅ Vaizdo įrašas išsaugotas: {output_filename}")
# Out:
# 🔄 Apdorojamas vaizdo įrašas: input_videos/input video.mp4
#
# 0: 384x640 10 cars, 1 bus, 3 trucks, 145.1ms
# Speed: 4.9ms preprocess, 145.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 cars, 2 trucks, 152.8ms
# Speed: 5.4ms preprocess, 152.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 1 bus, 3 trucks, 144.3ms
# Speed: 3.7ms preprocess, 144.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (66.92106182299983, 1522.8868996754022, 742.1568435541634, 3434.6680303520075)
#
# 0: 384x640 9 cars, 1 bus, 4 trucks, 163.2ms
# Speed: 3.7ms preprocess, 163.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (28.753974428265963, 1535.089868392657, 706.4225420029336, 3460.8856458620585)
#
# 0: 384x640 8 cars, 3 trucks, 145.9ms
# Speed: 7.3ms preprocess, 145.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-6.228139562467732, 1547.3037703660214, 673.392477358279, 3490.068086636781)
#
# 0: 384x640 6 cars, 3 trucks, 165.7ms
# Speed: 3.8ms preprocess, 165.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-41.492528988025356, 1556.676006973994, 637.608408838009, 3514.732846766534)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 151.9ms
# Speed: 3.2ms preprocess, 151.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-64.28702285245845, 1570.3121361161577, 613.1456153393065, 3546.1983460306656)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 166.6ms
# Speed: 5.9ms preprocess, 166.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-75.79379968388474, 1581.121470184084, 597.9086903762052, 3573.9139137024777)
#
# 0: 384x640 8 cars, 3 trucks, 136.5ms
# Speed: 6.4ms preprocess, 136.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-82.48154751658723, 1595.2716837176279, 586.15709453218, 3606.5913623289916)
#
# 0: 384x640 8 cars, 3 trucks, 200.5ms
# Speed: 4.7ms preprocess, 200.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-89.40690943854341, 1609.0009186381187, 571.9716701272126, 3638.4096930672804)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 219.9ms
# Speed: 4.8ms preprocess, 219.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-93.8774573913636, 1624.3298570353634, 557.4655350007926, 3668.372231062297)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 127.1ms
# Speed: 10.2ms preprocess, 127.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-98.71970674507094, 1637.05410938735, 540.8356774694287, 3695.823756954931)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 150.5ms
# Speed: 5.0ms preprocess, 150.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-101.9303384519028, 1648.2191374784813, 526.440615828693, 3727.740236988534)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 131.0ms
# Speed: 4.1ms preprocess, 131.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-104.30215933317999, 1661.7336935890326, 510.61956248245843, 3758.5784198687024)
#
# 0: 384x640 8 cars, 3 trucks, 125.4ms
# Speed: 4.4ms preprocess, 125.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-108.86257897570869, 1672.582054472931, 491.9871687898813, 3790.2912562383235)
#
# 0: 384x640 8 cars, 3 trucks, 140.0ms
# Speed: 5.7ms preprocess, 140.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-111.24467376050404, 1687.4786693843484, 474.6740762367093, 3826.3751690999547)
#
# 0: 384x640 9 cars, 1 bus, 4 trucks, 141.6ms
# Speed: 3.6ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-128.78749876714102, 1699.7957298640492, 461.8226163283604, 3855.821817426405)
#
# 0: 384x640 9 cars, 4 trucks, 141.1ms
# Speed: 4.9ms preprocess, 141.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-146.33031559323962, 1712.11279034375, 448.97114823947317, 3885.2684657528553)
#
# 0: 384x640 8 cars, 2 buss, 4 trucks, 135.7ms
# Speed: 3.5ms preprocess, 135.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-163.87312423879996, 1724.4298508234508, 436.11967197004765, 3914.7151140793057)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 124.5ms
# Speed: 4.1ms preprocess, 124.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-181.41592470382193, 1736.7469113031516, 423.26818752008376, 3944.161762405756)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 137.3ms
# Speed: 3.7ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-198.95871698830567, 1749.0639717828524, 410.41669488958155, 3973.608410732206)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 124.9ms
# Speed: 3.5ms preprocess, 124.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-216.5015010922511, 1761.3810322625532, 397.5651940785411, 4003.0550590586563)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 132.0ms
# Speed: 4.9ms preprocess, 132.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-234.04427701565817, 1773.698092742254, 384.7136850869623, 4032.501707385107)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 141.0ms
# Speed: 3.5ms preprocess, 141.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-251.58704475852699, 1786.0151532219547, 371.86216791484526, 4061.948355711557)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 137.9ms
# Speed: 11.9ms preprocess, 137.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-269.12980432085743, 1798.3322137016555, 359.01064256218984, 4091.395004038007)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 136.4ms
# Speed: 10.7ms preprocess, 136.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-286.6725557026496, 1810.6492741813563, 346.15910902899617, 4120.841652364457)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 143.2ms
# Speed: 5.7ms preprocess, 143.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-304.21529890390354, 1822.966334661057, 333.3075673152641, 4150.288300690908)
#
# 0: 384x640 6 cars, 4 trucks, 170.7ms
# Speed: 4.9ms preprocess, 170.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-321.7580339246191, 1835.2833951407579, 320.4560174209938, 4179.734949017358)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 241.7ms
# Speed: 6.2ms preprocess, 241.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-339.30076076479634, 1847.6004556204587, 307.6044593461852, 4209.181597343808)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 215.9ms
# Speed: 11.7ms preprocess, 215.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-356.84347942443526, 1859.9175161001594, 294.75289309083826, 4238.628245670258)
#
# 0: 384x640 6 cars, 4 trucks, 136.5ms
# Speed: 4.5ms preprocess, 136.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-374.38618990353586, 1872.2345765798602, 281.901318654953, 4268.074893996709)
#
# 0: 384x640 6 cars, 4 trucks, 148.8ms
# Speed: 5.4ms preprocess, 148.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-391.9288922020982, 1884.551637059561, 269.0497360385295, 4297.521542323158)
#
# 0: 384x640 6 cars, 4 trucks, 136.4ms
# Speed: 4.2ms preprocess, 136.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-409.47158632012224, 1896.8686975392618, 256.19814524156766, 4326.968190649609)
#
# 0: 384x640 6 cars, 4 trucks, 148.0ms
# Speed: 8.8ms preprocess, 148.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-427.014272257608, 1909.1857580189626, 243.34654626406746, 4356.414838976059)
#
# 0: 384x640 6 cars, 4 trucks, 144.8ms
# Speed: 4.7ms preprocess, 144.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-444.5569500145554, 1921.5028184986634, 230.494939106029, 4385.86148730251)
#
# 0: 384x640 4 cars, 4 trucks, 133.6ms
# Speed: 3.9ms preprocess, 133.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-462.0996195909645, 1933.8198789783642, 217.64332376745222, 4415.30813562896)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 129.1ms
# Speed: 3.5ms preprocess, 129.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-479.6422809868353, 1946.136939458065, 204.79170024833707, 4444.75478395541)
#
# 0: 384x640 6 cars, 4 trucks, 133.7ms
# Speed: 3.6ms preprocess, 133.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-497.1849342021678, 1958.4539999377657, 191.9400685486837, 4474.20143228186)
#
# 0: 384x640 7 cars, 4 trucks, 143.1ms
# Speed: 4.3ms preprocess, 143.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-514.7275792369619, 1970.7710604174665, 179.08842866849204, 4503.648080608311)
#
# 0: 384x640 5 cars, 5 trucks, 149.8ms
# Speed: 12.6ms preprocess, 149.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-532.2702160912178, 1983.0881208971673, 166.23678060776206, 4533.0947289347605)
#
# 0: 384x640 5 cars, 5 trucks, 144.1ms
# Speed: 4.2ms preprocess, 144.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-549.8128447649353, 1995.405181376868, 153.38512436649376, 4562.541377261211)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 134.7ms
# Speed: 5.0ms preprocess, 134.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-567.3554652581146, 2007.7222418565689, 140.53345994468714, 4591.9880255876615)
#
# 0: 384x640 5 cars, 5 trucks, 161.3ms
# Speed: 4.4ms preprocess, 161.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-584.8980775707555, 2020.0393023362697, 127.6817873423422, 4621.434673914112)
#
# 0: 384x640 5 cars, 5 trucks, 135.2ms
# Speed: 4.1ms preprocess, 135.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-602.4406817028582, 2032.3563628159704, 114.83010655945895, 4650.881322240562)
#
# 0: 384x640 5 cars, 5 trucks, 127.8ms
# Speed: 3.6ms preprocess, 127.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-619.9832776544225, 2044.6734232956712, 101.97841759603739, 4680.327970567012)
#
# 0: 384x640 4 cars, 5 trucks, 128.9ms
# Speed: 3.8ms preprocess, 128.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-637.5258654254485, 2056.990483775372, 89.12672045207762, 4709.7746188934625)
#
# 0: 384x640 4 cars, 5 trucks, 225.4ms
# Speed: 5.1ms preprocess, 225.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-655.0684450159363, 2069.3075442550726, 76.27501512757942, 4739.221267219913)
#
# 0: 384x640 4 cars, 5 trucks, 218.8ms
# Speed: 11.5ms preprocess, 218.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-672.6110164258857, 2081.6246047347736, 63.42330162254291, 4768.667915546363)
#
# 0: 384x640 5 cars, 5 trucks, 161.7ms
# Speed: 5.0ms preprocess, 161.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-690.1535796552968, 2093.9416652144746, 50.57157993696819, 4798.114563872814)
#
# 0: 384x640 4 cars, 5 trucks, 146.4ms
# Speed: 5.8ms preprocess, 146.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-707.6961347041696, 2106.258725694175, 37.71985007085516, 4827.5612121992635)
#
# 0: 384x640 4 cars, 5 trucks, 142.3ms
# Speed: 3.6ms preprocess, 142.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-725.238681572504, 2118.5757861738757, 24.86811202420381, 4857.007860525713)
#
# 0: 384x640 4 cars, 5 trucks, 148.5ms
# Speed: 3.9ms preprocess, 148.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-742.7812202603002, 2130.8928466535767, 12.016365797014146, 4886.4545088521645)
#
# 0: 384x640 4 cars, 5 trucks, 144.4ms
# Speed: 3.4ms preprocess, 144.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-760.3237507675581, 2143.2099071332777, -0.8353886107138351, 4915.901157178614)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 129.2ms
# Speed: 5.1ms preprocess, 129.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-777.8662730942776, 2155.5269676129783, -13.687151198980132, 4945.347805505065)
#
# 0: 384x640 5 cars, 5 trucks, 137.3ms
# Speed: 4.2ms preprocess, 137.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-795.4087872404589, 2167.844028092679, -26.538921967784745, 4974.794453831515)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 155.0ms
# Speed: 4.7ms preprocess, 155.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-812.9512932061018, 2180.16108857238, -39.390700917127674, 5004.241102157965)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 122.4ms
# Speed: 3.7ms preprocess, 122.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-830.4937909912065, 2192.478149052081, -52.24248804700892, 5033.687750484416)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 133.4ms
# Speed: 4.2ms preprocess, 133.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-848.0362805957728, 2204.7952095317814, -65.09428335742848, 5063.134398810866)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 150.6ms
# Speed: 4.1ms preprocess, 150.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-865.5787620198009, 2217.112270011482, -77.94608684838636, 5092.581047137315)
#
# 0: 384x640 5 cars, 5 trucks, 171.8ms
# Speed: 4.6ms preprocess, 171.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-883.1212352632906, 2229.429330491183, -90.79789851988244, 5122.027695463767)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 148.2ms
# Speed: 7.6ms preprocess, 148.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-900.663700326242, 2241.746390970884, -103.64971837191683, 5151.474343790216)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 151.9ms
# Speed: 4.6ms preprocess, 151.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-918.2061572086551, 2254.0634514505846, -116.50154640448966, 5180.920992116667)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 140.2ms
# Speed: 3.7ms preprocess, 140.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-935.7486059105299, 2266.380511930285, -129.3533826176008, 5210.367640443117)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 151.6ms
# Speed: 6.0ms preprocess, 151.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-953.2910464318666, 2278.697572409986, -142.20522701125026, 5239.814288769567)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 246.2ms
# Speed: 4.0ms preprocess, 246.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-970.8334787726648, 2291.014632889687, -155.05707958543792, 5269.260937096018)
#
# 0: 384x640 5 cars, 2 buss, 5 trucks, 216.4ms
# Speed: 6.6ms preprocess, 216.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚗 Sekamas automobilis ID: 1 ties (-988.3759029329246, 2303.3316933693877, -167.9089403401639, 5298.707585422468)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 152.2ms
# Speed: 9.6ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 136.0ms
# Speed: 5.3ms preprocess, 136.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 120.8ms
# Speed: 10.5ms preprocess, 120.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 134.4ms
# Speed: 3.8ms preprocess, 134.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 174.0ms
# Speed: 10.2ms preprocess, 174.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 132.4ms
# Speed: 5.0ms preprocess, 132.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 172.8ms
# Speed: 4.2ms preprocess, 172.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 127.4ms
# Speed: 3.9ms preprocess, 127.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 132.5ms
# Speed: 3.6ms preprocess, 132.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 125.7ms
# Speed: 5.7ms preprocess, 125.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 152.8ms
# Speed: 4.2ms preprocess, 152.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 5 trucks, 132.9ms
# Speed: 19.4ms preprocess, 132.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 159.9ms
# Speed: 7.0ms preprocess, 159.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 153.2ms
# Speed: 4.3ms preprocess, 153.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 143.5ms
# Speed: 10.1ms preprocess, 143.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 201.1ms
# Speed: 3.8ms preprocess, 201.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 192.3ms
# Speed: 3.6ms preprocess, 192.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 139.4ms
# Speed: 6.0ms preprocess, 139.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 121.1ms
# Speed: 3.5ms preprocess, 121.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 138.6ms
# Speed: 4.1ms preprocess, 138.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 132.8ms
# Speed: 3.4ms preprocess, 132.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 138.2ms
# Speed: 5.2ms preprocess, 138.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 162.9ms
# Speed: 4.9ms preprocess, 162.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 159.7ms
# Speed: 6.9ms preprocess, 159.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 131.7ms
# Speed: 3.4ms preprocess, 131.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 132.1ms
# Speed: 4.1ms preprocess, 132.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 133.4ms
# Speed: 3.7ms preprocess, 133.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 137.1ms
# Speed: 6.9ms preprocess, 137.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 152.0ms
# Speed: 4.3ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 148.0ms
# Speed: 4.8ms preprocess, 148.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 155.1ms
# Speed: 4.2ms preprocess, 155.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 5 trucks, 153.7ms
# Speed: 6.4ms preprocess, 153.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 trucks, 197.2ms
# Speed: 3.6ms preprocess, 197.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 trucks, 203.9ms
# Speed: 9.3ms preprocess, 203.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 179.0ms
# Speed: 6.9ms preprocess, 179.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 143.9ms
# Speed: 3.8ms preprocess, 143.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 165.8ms
# Speed: 4.5ms preprocess, 165.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 155.7ms
# Speed: 4.8ms preprocess, 155.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 140.2ms
# Speed: 4.4ms preprocess, 140.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 139.8ms
# Speed: 4.6ms preprocess, 139.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 153.9ms
# Speed: 10.3ms preprocess, 153.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 5 trucks, 141.2ms
# Speed: 4.5ms preprocess, 141.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 trucks, 129.8ms
# Speed: 10.7ms preprocess, 129.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 5 trucks, 160.5ms
# Speed: 6.7ms preprocess, 160.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 136.0ms
# Speed: 3.6ms preprocess, 136.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 133.9ms
# Speed: 11.6ms preprocess, 133.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 153.1ms
# Speed: 3.7ms preprocess, 153.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 trucks, 136.4ms
# Speed: 7.5ms preprocess, 136.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 4 trucks, 185.4ms
# Speed: 5.9ms preprocess, 185.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 trucks, 239.3ms
# Speed: 4.6ms preprocess, 239.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 150.5ms
# Speed: 7.3ms preprocess, 150.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 143.3ms
# Speed: 6.8ms preprocess, 143.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 160.6ms
# Speed: 4.4ms preprocess, 160.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 142.2ms
# Speed: 3.7ms preprocess, 142.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 150.6ms
# Speed: 4.0ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 164.0ms
# Speed: 6.1ms preprocess, 164.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 137.5ms
# Speed: 3.4ms preprocess, 137.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 121.4ms
# Speed: 11.2ms preprocess, 121.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 145.8ms
# Speed: 4.3ms preprocess, 145.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 152.2ms
# Speed: 5.6ms preprocess, 152.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 149.7ms
# Speed: 6.7ms preprocess, 149.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 167.4ms
# Speed: 4.2ms preprocess, 167.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 141.1ms
# Speed: 5.2ms preprocess, 141.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 130.7ms
# Speed: 4.5ms preprocess, 130.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 143.0ms
# Speed: 5.0ms preprocess, 143.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 train, 2 trucks, 132.6ms
# Speed: 5.2ms preprocess, 132.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 train, 2 trucks, 122.7ms
# Speed: 3.4ms preprocess, 122.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 2 trucks, 153.6ms
# Speed: 4.0ms preprocess, 153.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 168.8ms
# Speed: 7.8ms preprocess, 168.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 train, 2 trucks, 215.5ms
# Speed: 9.3ms preprocess, 215.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 train, 2 trucks, 246.4ms
# Speed: 6.1ms preprocess, 246.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 159.8ms
# Speed: 4.1ms preprocess, 159.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 train, 2 trucks, 175.5ms
# Speed: 6.4ms preprocess, 175.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 177.1ms
# Speed: 4.0ms preprocess, 177.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 149.1ms
# Speed: 3.6ms preprocess, 149.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 143.7ms
# Speed: 3.9ms preprocess, 143.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 140.8ms
# Speed: 4.0ms preprocess, 140.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 136.7ms
# Speed: 9.3ms preprocess, 136.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 train, 2 trucks, 137.9ms
# Speed: 3.7ms preprocess, 137.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 140.6ms
# Speed: 3.3ms preprocess, 140.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 136.9ms
# Speed: 3.4ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 146.4ms
# Speed: 3.7ms preprocess, 146.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 141.3ms
# Speed: 3.3ms preprocess, 141.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 150.0ms
# Speed: 8.0ms preprocess, 150.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 4 trucks, 157.0ms
# Speed: 6.2ms preprocess, 157.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 154.3ms
# Speed: 4.5ms preprocess, 154.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 2 trucks, 162.1ms
# Speed: 4.1ms preprocess, 162.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 3 trucks, 146.1ms
# Speed: 5.2ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 152.8ms
# Speed: 7.2ms preprocess, 152.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 1 train, 3 trucks, 129.9ms
# Speed: 5.9ms preprocess, 129.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 2 trucks, 215.7ms
# Speed: 10.8ms preprocess, 215.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 221.1ms
# Speed: 5.2ms preprocess, 221.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 170.6ms
# Speed: 10.5ms preprocess, 170.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 149.4ms
# Speed: 4.1ms preprocess, 149.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 166.2ms
# Speed: 6.4ms preprocess, 166.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 5 trucks, 140.2ms
# Speed: 5.1ms preprocess, 140.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 133.0ms
# Speed: 4.7ms preprocess, 133.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 147.7ms
# Speed: 5.2ms preprocess, 147.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 140.4ms
# Speed: 4.8ms preprocess, 140.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 138.9ms
# Speed: 4.7ms preprocess, 138.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 146.6ms
# Speed: 6.9ms preprocess, 146.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 133.1ms
# Speed: 3.8ms preprocess, 133.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 125.8ms
# Speed: 3.4ms preprocess, 125.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 147.6ms
# Speed: 11.9ms preprocess, 147.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 159.9ms
# Speed: 5.0ms preprocess, 159.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 144.9ms
# Speed: 7.4ms preprocess, 144.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 148.8ms
# Speed: 6.5ms preprocess, 148.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 138.1ms
# Speed: 5.1ms preprocess, 138.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 169.4ms
# Speed: 5.3ms preprocess, 169.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 223.8ms
# Speed: 4.7ms preprocess, 223.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 198.8ms
# Speed: 9.3ms preprocess, 198.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 146.0ms
# Speed: 7.5ms preprocess, 146.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 146.0ms
# Speed: 3.9ms preprocess, 146.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 147.7ms
# Speed: 4.7ms preprocess, 147.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 142.3ms
# Speed: 4.3ms preprocess, 142.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 144.8ms
# Speed: 3.7ms preprocess, 144.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 133.0ms
# Speed: 4.5ms preprocess, 133.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 136.6ms
# Speed: 5.6ms preprocess, 136.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 148.5ms
# Speed: 3.7ms preprocess, 148.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 133.9ms
# Speed: 5.6ms preprocess, 133.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 141.3ms
# Speed: 5.5ms preprocess, 141.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 134.3ms
# Speed: 4.2ms preprocess, 134.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 157.1ms
# Speed: 4.0ms preprocess, 157.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 144.5ms
# Speed: 4.8ms preprocess, 144.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 4 buss, 3 trucks, 152.7ms
# Speed: 8.9ms preprocess, 152.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 135.6ms
# Speed: 4.7ms preprocess, 135.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 156.6ms
# Speed: 4.3ms preprocess, 156.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 152.3ms
# Speed: 6.0ms preprocess, 152.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 4 trucks, 164.4ms
# Speed: 10.5ms preprocess, 164.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 207.9ms
# Speed: 5.5ms preprocess, 207.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 5 trucks, 157.5ms
# Speed: 3.4ms preprocess, 157.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 165.8ms
# Speed: 5.3ms preprocess, 165.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 5 trucks, 154.0ms
# Speed: 4.8ms preprocess, 154.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trucks, 130.7ms
# Speed: 14.1ms preprocess, 130.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 2 buss, 3 trucks, 138.9ms
# Speed: 3.5ms preprocess, 138.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 3 trucks, 124.6ms
# Speed: 4.6ms preprocess, 124.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 cars, 3 buss, 3 trucks, 137.5ms
# Speed: 13.2ms preprocess, 137.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trucks, 147.2ms
# Speed: 3.7ms preprocess, 147.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 4 buss, 3 trucks, 130.0ms
# Speed: 10.3ms preprocess, 130.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 4 trucks, 166.4ms
# Speed: 8.0ms preprocess, 166.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 150.4ms
# Speed: 7.2ms preprocess, 150.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 4 buss, 3 trucks, 140.3ms
# Speed: 3.5ms preprocess, 140.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 buss, 2 trucks, 142.5ms
# Speed: 5.7ms preprocess, 142.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 5 buss, 3 trucks, 164.1ms
# Speed: 3.7ms preprocess, 164.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 134.8ms
# Speed: 5.5ms preprocess, 134.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 205.3ms
# Speed: 3.7ms preprocess, 205.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 202.7ms
# Speed: 5.6ms preprocess, 202.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 129.7ms
# Speed: 4.2ms preprocess, 129.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 127.8ms
# Speed: 3.5ms preprocess, 127.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 4 buss, 3 trucks, 131.7ms
# Speed: 7.5ms preprocess, 131.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 4 buss, 3 trucks, 136.3ms
# Speed: 3.4ms preprocess, 136.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 3 trucks, 131.4ms
# Speed: 10.6ms preprocess, 131.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 128.4ms
# Speed: 6.6ms preprocess, 128.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 129.7ms
# Speed: 6.1ms preprocess, 129.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 1 stop sign, 138.3ms
# Speed: 3.7ms preprocess, 138.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 2 buss, 2 trucks, 1 stop sign, 154.2ms
# Speed: 8.3ms preprocess, 154.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 1 stop sign, 145.0ms
# Speed: 4.5ms preprocess, 145.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 1 stop sign, 144.6ms
# Speed: 3.8ms preprocess, 144.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 1 stop sign, 145.7ms
# Speed: 3.2ms preprocess, 145.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 123.7ms
# Speed: 9.1ms preprocess, 123.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 3 trucks, 151.8ms
# Speed: 10.4ms preprocess, 151.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 5 trucks, 150.0ms
# Speed: 5.4ms preprocess, 150.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 3 trucks, 147.7ms
# Speed: 7.4ms preprocess, 147.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 4 trucks, 154.1ms
# Speed: 9.2ms preprocess, 154.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 3 trucks, 224.1ms
# Speed: 4.3ms preprocess, 224.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 2 trucks, 176.8ms
# Speed: 7.0ms preprocess, 176.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 132.4ms
# Speed: 3.6ms preprocess, 132.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 128.8ms
# Speed: 3.7ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 160.0ms
# Speed: 4.4ms preprocess, 160.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 125.3ms
# Speed: 4.9ms preprocess, 125.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 5 trucks, 137.4ms
# Speed: 3.8ms preprocess, 137.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 143.1ms
# Speed: 4.5ms preprocess, 143.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 148.1ms
# Speed: 3.5ms preprocess, 148.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 169.1ms
# Speed: 4.0ms preprocess, 169.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 138.7ms
# Speed: 4.3ms preprocess, 138.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 140.5ms
# Speed: 4.4ms preprocess, 140.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 137.6ms
# Speed: 4.2ms preprocess, 137.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 3 trucks, 133.2ms
# Speed: 6.2ms preprocess, 133.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 3 buss, 4 trucks, 158.8ms
# Speed: 6.6ms preprocess, 158.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 4 trucks, 160.0ms
# Speed: 6.8ms preprocess, 160.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 5 trucks, 161.3ms
# Speed: 4.6ms preprocess, 161.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 180.5ms
# Speed: 4.1ms preprocess, 180.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 4 trucks, 226.7ms
# Speed: 4.5ms preprocess, 226.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 3 buss, 5 trucks, 141.1ms
# Speed: 4.0ms preprocess, 141.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 5 trucks, 211.6ms
# Speed: 6.2ms preprocess, 211.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 219.0ms
# Speed: 5.8ms preprocess, 219.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 154.1ms
# Speed: 12.5ms preprocess, 154.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 4 trucks, 157.7ms
# Speed: 3.6ms preprocess, 157.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 168.6ms
# Speed: 4.0ms preprocess, 168.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 4 trucks, 132.2ms
# Speed: 8.7ms preprocess, 132.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 141.4ms
# Speed: 11.7ms preprocess, 141.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 137.4ms
# Speed: 4.6ms preprocess, 137.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 142.6ms
# Speed: 3.6ms preprocess, 142.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 142.0ms
# Speed: 3.3ms preprocess, 142.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 136.2ms
# Speed: 4.3ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 117.5ms
# Speed: 10.4ms preprocess, 117.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 2 trucks, 159.2ms
# Speed: 4.9ms preprocess, 159.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 3 trucks, 150.1ms
# Speed: 5.6ms preprocess, 150.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 3 trucks, 223.1ms
# Speed: 7.3ms preprocess, 223.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 241.5ms
# Speed: 10.5ms preprocess, 241.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 135.9ms
# Speed: 4.1ms preprocess, 135.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 124.6ms
# Speed: 3.9ms preprocess, 124.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 136.2ms
# Speed: 3.6ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 151.3ms
# Speed: 5.9ms preprocess, 151.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 3 trucks, 156.9ms
# Speed: 4.4ms preprocess, 156.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 144.7ms
# Speed: 4.4ms preprocess, 144.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 3 trucks, 130.0ms
# Speed: 4.7ms preprocess, 130.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 128.5ms
# Speed: 3.7ms preprocess, 128.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 139.3ms
# Speed: 4.5ms preprocess, 139.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 122.9ms
# Speed: 21.6ms preprocess, 122.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 146.5ms
# Speed: 4.2ms preprocess, 146.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 172.7ms
# Speed: 5.4ms preprocess, 172.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 129.3ms
# Speed: 3.7ms preprocess, 129.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 132.3ms
# Speed: 3.8ms preprocess, 132.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 3 trucks, 151.8ms
# Speed: 7.3ms preprocess, 151.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 133.7ms
# Speed: 10.7ms preprocess, 133.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 151.1ms
# Speed: 3.5ms preprocess, 151.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 199.9ms
# Speed: 6.0ms preprocess, 199.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 211.1ms
# Speed: 6.0ms preprocess, 211.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 142.1ms
# Speed: 15.4ms preprocess, 142.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 134.3ms
# Speed: 3.4ms preprocess, 134.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 151.1ms
# Speed: 4.8ms preprocess, 151.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 149.4ms
# Speed: 3.9ms preprocess, 149.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 149.3ms
# Speed: 6.4ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 buss, 2 trucks, 151.3ms
# Speed: 5.4ms preprocess, 151.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 5 trucks, 167.8ms
# Speed: 4.9ms preprocess, 167.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 154.0ms
# Speed: 11.5ms preprocess, 154.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 147.1ms
# Speed: 4.7ms preprocess, 147.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 4 trucks, 166.4ms
# Speed: 4.8ms preprocess, 166.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 160.3ms
# Speed: 4.2ms preprocess, 160.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 157.6ms
# Speed: 3.9ms preprocess, 157.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 137.7ms
# Speed: 7.3ms preprocess, 137.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 buss, 3 trucks, 156.3ms
# Speed: 5.5ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 buss, 2 trucks, 163.3ms
# Speed: 4.4ms preprocess, 163.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 3 trucks, 152.0ms
# Speed: 4.1ms preprocess, 152.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 150.3ms
# Speed: 4.3ms preprocess, 150.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 213.9ms
# Speed: 3.6ms preprocess, 213.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 buss, 2 trucks, 204.6ms
# Speed: 5.9ms preprocess, 204.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 152.5ms
# Speed: 4.1ms preprocess, 152.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 3 trucks, 132.4ms
# Speed: 3.8ms preprocess, 132.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 4 trucks, 117.2ms
# Speed: 3.6ms preprocess, 117.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ✅ Vaizdo įrašas išsaugotas: output_videos/input video.mp4
